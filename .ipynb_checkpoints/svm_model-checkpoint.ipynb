# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV, StratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import joblib
import numpy as np

# %%
dataset = pd.read_csv(r"drug_regulatory_classification_dataset.csv")
dataset.head()
# Out:
#    Dosage_mg  Price_Per_Unit  Production_Cost  Marketing_Spend  \
# 0        250          364.22           246.49        159132.53
# 1        500          112.86            73.22        260595.45
# 2        200          197.24           100.72        106818.45
# 3        500          373.55           264.76        231304.59
# 4        500          353.87           277.29        319403.02
#
#    Clinical_Trial_Phase  Side_Effect_Severity_Score  Abuse_Potential_Score  \
# 0                     3                        4.26                   2.52
# 1                     2                        8.12                   1.80
# 2                     3                        1.58                   1.47
# 3                     4                        1.72                   1.61
# 4                     2                        9.64                   0.45
#
#    Prescription_Rate  Hospital_Distribution_Percentage  \
# 0               0.74                             57.93
# ...

# %%
x = dataset.iloc[:, :-1]
y = dataset.iloc[:, -1]

# %%
x.head()
# Out:
#    Dosage_mg  Price_Per_Unit  Production_Cost  Marketing_Spend  \
# 0        250          364.22           246.49        159132.53
# 1        500          112.86            73.22        260595.45
# 2        200          197.24           100.72        106818.45
# 3        500          373.55           264.76        231304.59
# 4        500          353.87           277.29        319403.02
#
#    Clinical_Trial_Phase  Side_Effect_Severity_Score  Abuse_Potential_Score  \
# 0                     3                        4.26                   2.52
# 1                     2                        8.12                   1.80
# 2                     3                        1.58                   1.47
# 3                     4                        1.72                   1.61
# 4                     2                        9.64                   0.45
#
#    Prescription_Rate  Hospital_Distribution_Percentage  \
# 0               0.74                             57.93
# ...

# %%
y.head()
# Out:
# 0    Non-Regulated Drug
# 1    Non-Regulated Drug
# 2    Non-Regulated Drug
# 3    Non-Regulated Drug
# 4    Non-Regulated Drug
# Name: Target_Regulatory_Class, dtype: str

# %%
# Encode target
le = LabelEncoder()
y = le.fit_transform(y.astype(str))

# %%
#load pipeline
preprocess_pipeline = joblib.load('preprocess_pipeline.pkl')

# %%
# Train-test split (before preprocessing)
X_train, X_test, y_train, y_test = train_test_split(
    x, y,
    test_size=0.2,
    random_state=42,
    stratify=y
)

# %%
# Full pipeline
pipeline = Pipeline([
    ("preprocess", preprocess_pipeline),
    ("model", SVC(probability=True))
])

# %%
# param = {
#     "C": [1,10],
#     "kernel": ["linear"],
#     "gamma": ["scale", "auto"]
# }

# %%
# grid_search = GridSearchCV(
#     estimator=svm_model,
#     param_grid=param,
#     cv=3,
#     n_jobs=-1,
# )

# %%
# print(set(y_train))
# print(type(y_train[0]))

# %%
# grid_search.fit(x_train, y_train)

# %%
# print("Best Parameters:", grid_search.best_params_)

# %%
# best_svm = grid_search.best_estimator_

# %%
# y_pred = best_svm.predict(x_test)

# %%
# print("Accuracy:", accuracy_score(y_test, y_pred))

# %%
# print(confusion_matrix(y_test, y_pred))

# %%
# print(classification_report(y_test, y_pred))

# %%
# Improved but faster hyperparameter space
param_dist = {
    "model__C": np.linspace(0.5, 10, 10),   # focused range
    "model__kernel": ["rbf"],               # best kernel for most datasets
    "model__gamma": ["scale", "auto", 0.01, 0.1],
    "model__class_weight": [None, "balanced"]
}

# %%
# Faster cross validation
cv = StratifiedKFold(
    n_splits=3,
    shuffle=True,
    random_state=42
)

# %%
# Faster Randomized Search
random_search = RandomizedSearchCV(
    pipeline,
    param_distributions=param_dist,
    n_iter=10,          # reduced iterations
    cv=cv,
    scoring="accuracy",
    n_jobs=-1,
    verbose=2,
    random_state=42
)

# %%
# Train model 
random_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=3, random_state=42, shuffle=True),
#                    estimator=Pipeline(steps=[('preprocess',
#                                               ColumnTransformer(transformers=[('numerical',
#                                                                                Pipeline(steps=[('imputer',
#                                                                                                 SimpleImputer(strategy='median')),
#                                                                                                ('winsorizer',
#                                                                                                 Winsorizer(capping_method='iqr',
#                                                                                                            fold=1.5,
# ...

# %%
print("Best Parameters:", random_search.best_params_)
# Out:
# Best Parameters: {'model__kernel': 'rbf', 'model__gamma': 'scale', 'model__class_weight': None, 'model__C': np.float64(0.5)}

# %%
best_svm = random_search.best_estimator_

# %%
y_pred = best_svm.predict(X_test)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7420833333333333

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[8053  373    0]
#  [2122  852    0]
#  [ 539   61    0]]

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.96      0.84      8426
#            1       0.66      0.29      0.40      2974
#            2       0.00      0.00      0.00       600
#
#     accuracy                           0.74     12000
#    macro avg       0.47      0.41      0.41     12000
# weighted avg       0.69      0.74      0.69     12000
# C:\Users\saksh\AppData\Roaming\Python\Python313\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# ...

# %%
joblib.dump(random_search.best_estimator_, "svm_model.pkl")
# Out:
# ['svm_model.pkl']

# %%
joblib.load('svm_model.pkl')
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('numerical',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('winsorizer',
#                                                                    Winsorizer(capping_method='iqr',
#                                                                               fold=1.5,
#                                                                               tail='both')),
#                                                                   ('scaler',
#                                                                    MinMaxScaler())]),
#                                                   Index(['Dosage_mg', 'Price_Per_Unit', 'Production_Cost', 'Marketing_Spend',
# ...
